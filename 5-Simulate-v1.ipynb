# %%
import tensorflow as tf
import scipy.misc
import model
# from subprocess import call
# import time
import csv
import numpy as np
import config as cfg
import cv2

sess = tf.InteractiveSession()
saver = tf.train.Saver()
saver.restore(sess, "save/model.ckpt")

xs = []
ys = []

increased_path = '../../dataset/20200408-revised/3-increased'
with open(increased_path + '/data.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
    for row in spamreader:
        # print(row[0], row[1])
        xs.append(row[0])
        ys.append(row[1])

# print(xs[0])

"""
# 이미지를 읽고, 크기변환, normalize
cv2.resize(cv2.imread(filepath)[cfg.modelheight:], dsize=(200, 66)) / 255.0)

# 예시로 출력 해 보자
# cv2.imshow("src : " + str(y_out[i]), x_out[i])
# print('filepath : ' + filepath)
# cv2.waitKey(0)

def getDirectionString(dir):
    if dir == 0:  # 0 정지!!!
        return 'Stop'
    elif dir == 1:  # 1 = 좌회전
        return 'Left'
    elif int(row[1]) == 2:  # 2 = 전진
        return 'Forward'
    elif int(row[1]) == 3:  # 3 = 우회전
        return 'Right'
    
    return 'Error'
"""
i = 0
correct_num = 0
missed_forward = 0
missed_left = 0
missed_right = 0
missed_etc = 0

# while(cv2.waitKey(10) != ord('q')):
for i in range(len(xs)):
    filepath = increased_path + '/' + xs[i]
    # full_image = scipy.misc.imread(filepath, mode="RGB")
    full_image = cv2.imread(filepath)
    # image_feed2model = scipy.misc.imresize(full_image[cfg.modelheight:], [66, 200]) / 255.0
    image_feed2model = cv2.resize(full_image[cfg.modelheight:], dsize=(200, 66)) / 255.0
    # image_largescale = scipy.misc.imresize(full_image[cfg.modelheight:], [66 * 3, 200 * 3])
    image_largescale = cv2.resize(full_image[cfg.modelheight:], dsize=(200*3, 66*3)) / 255.0
    
    degrees = model.y.eval(feed_dict={model.x: [image_feed2model], model.keep_prob: 1.0})
    # print("Label y: " + ys[i], 'prediced value:', np.argmax(degrees, axis=1))
    if False:
        # cv2.imshow("Feed", cv2.cvtColor(image_largescale, cv2.COLOR_RGB2BGR))
        cv2.imshow("Feed", image_largescale)
        # cv2.imshow("Original", cv2.cvtColor(full_image, cv2.COLOR_RGB2BGR))
        cv2.imshow("Original", full_image)

    if int(ys[i]) == np.argmax(degrees, axis=1):
        correct_num += 1
    else:
        if int(ys[i]) == 1:  # LEFT
            missed_left = missed_left + 1
        elif int(ys[i]) == 2:  # FORWARD
            missed_forward = missed_forward + 1
        elif int(ys[i]) == 3:  # RIGHT
            missed_right = missed_right + 1
        else:  # etc
            missed_etc = missed_etc + 1

    if (i > 0) and (i % 100 == 0):
        print('확인한 사진 수 :', i, '| 정확도: ', round((correct_num/i)*100, 2))


# summary
print('LEFT 를 못맞춘 경우의 수: ' + str(missed_left))
print('RIGHT 를 못맞춘 경우의 수: ' + str(missed_right))
print('FORWARD 를 못맞춘 경우의 수: ' + str(missed_forward))
print('ETC 를 못맞춘 경우의 수: ' + str(missed_etc))

cv2.destroyAllWindows()

# THE END
# Out:
# WARNING:tensorflow:From /tf/workspace/UsingColorPhotos/model.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tf/workspace/UsingColorPhotos/model.py:6: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /tf/workspace/UsingColorPhotos/model.py:72: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# model read
# INFO:tensorflow:Restoring parameters from save/model.ckpt
# 확인한 사진 수 : 100 | 정확도:  98.0
# 확인한 사진 수 : 200 | 정확도:  97.5
# 확인한 사진 수 : 300 | 정확도:  97.33
# 확인한 사진 수 : 400 | 정확도:  97.25
# 확인한 사진 수 : 500 | 정확도:  97.2
# 확인한 사진 수 : 600 | 정확도:  97.33
# 확인한 사진 수 : 700 | 정확도:  97.43
# 확인한 사진 수 : 800 | 정확도:  97.0
# 확인한 사진 수 : 900 | 정확도:  97.22
# 확인한 사진 수 : 1000 | 정확도:  97.2
# 확인한 사진 수 : 1100 | 정확도:  97.27
# 확인한 사진 수 : 1200 | 정확도:  97.5
# 확인한 사진 수 : 1300 | 정확도:  97.62
# 확인한 사진 수 : 1400 | 정확도:  97.64
# 확인한 사진 수 : 1500 | 정확도:  97.67
# 확인한 사진 수 : 1600 | 정확도:  97.62
# 확인한 사진 수 : 1700 | 정확도:  97.53
# 확인한 사진 수 : 1800 | 정확도:  97.44
# 확인한 사진 수 : 1900 | 정확도:  97.42
# 확인한 사진 수 : 2000 | 정확도:  97.45
# 확인한 사진 수 : 2100 | 정확도:  97.52
# 확인한 사진 수 : 2200 | 정확도:  97.55
# 확인한 사진 수 : 2300 | 정확도:  97.57
# 확인한 사진 수 : 2400 | 정확도:  97.67
# 확인한 사진 수 : 2500 | 정확도:  97.6
# 확인한 사진 수 : 2600 | 정확도:  97.65
# 확인한 사진 수 : 2700 | 정확도:  97.67
# 확인한 사진 수 : 2800 | 정확도:  97.71
# 확인한 사진 수 : 2900 | 정확도:  97.72
# 확인한 사진 수 : 3000 | 정확도:  97.7
# 확인한 사진 수 : 3100 | 정확도:  97.65
# 확인한 사진 수 : 3200 | 정확도:  97.69
# 확인한 사진 수 : 3300 | 정확도:  97.7
# 확인한 사진 수 : 3400 | 정확도:  97.71
# 확인한 사진 수 : 3500 | 정확도:  97.69
# 확인한 사진 수 : 3600 | 정확도:  97.69
# 확인한 사진 수 : 3700 | 정확도:  97.73
# 확인한 사진 수 : 3800 | 정확도:  97.76
# 확인한 사진 수 : 3900 | 정확도:  97.79
# 확인한 사진 수 : 4000 | 정확도:  97.78
# 확인한 사진 수 : 4100 | 정확도:  97.8
# 확인한 사진 수 : 4200 | 정확도:  97.83
# 확인한 사진 수 : 4300 | 정확도:  97.88
# 확인한 사진 수 : 4400 | 정확도:  97.91
# 확인한 사진 수 : 4500 | 정확도:  97.93
# 확인한 사진 수 : 4600 | 정확도:  97.91
# 확인한 사진 수 : 4700 | 정확도:  97.87
# 확인한 사진 수 : 4800 | 정확도:  97.88
# 확인한 사진 수 : 4900 | 정확도:  97.92
# 확인한 사진 수 : 5000 | 정확도:  97.94
# 확인한 사진 수 : 5100 | 정확도:  97.96
# 확인한 사진 수 : 5200 | 정확도:  97.96
# 확인한 사진 수 : 5300 | 정확도:  98.0
# 확인한 사진 수 : 5400 | 정확도:  98.0
# 확인한 사진 수 : 5500 | 정확도:  98.04
# 확인한 사진 수 : 5600 | 정확도:  98.04
# 확인한 사진 수 : 5700 | 정확도:  98.02
# 확인한 사진 수 : 5800 | 정확도:  98.05
# 확인한 사진 수 : 5900 | 정확도:  98.08
# 확인한 사진 수 : 6000 | 정확도:  98.1
# 확인한 사진 수 : 6100 | 정확도:  98.13
# 확인한 사진 수 : 6200 | 정확도:  98.16
# 확인한 사진 수 : 6300 | 정확도:  98.13
# 확인한 사진 수 : 6400 | 정확도:  98.09
# 확인한 사진 수 : 6500 | 정확도:  98.12
# 확인한 사진 수 : 6600 | 정확도:  98.15
# 확인한 사진 수 : 6700 | 정확도:  98.18
# 확인한 사진 수 : 6800 | 정확도:  98.21
# 확인한 사진 수 : 6900 | 정확도:  98.23
# 확인한 사진 수 : 7000 | 정확도:  98.26
# 확인한 사진 수 : 7100 | 정확도:  98.28
# 확인한 사진 수 : 7200 | 정확도:  98.31
# 확인한 사진 수 : 7300 | 정확도:  98.33
# 확인한 사진 수 : 7400 | 정확도:  98.35
# 확인한 사진 수 : 7500 | 정확도:  98.37
# 확인한 사진 수 : 7600 | 정확도:  98.39
# 확인한 사진 수 : 7700 | 정확도:  98.42
# 확인한 사진 수 : 7800 | 정확도:  98.44
# 확인한 사진 수 : 7900 | 정확도:  98.46
# 확인한 사진 수 : 8000 | 정확도:  98.47
# 확인한 사진 수 : 8100 | 정확도:  98.49
# 확인한 사진 수 : 8200 | 정확도:  98.5
# 확인한 사진 수 : 8300 | 정확도:  98.52
# 확인한 사진 수 : 8400 | 정확도:  98.54
# 확인한 사진 수 : 8500 | 정확도:  98.53
# 확인한 사진 수 : 8600 | 정확도:  98.53
# 확인한 사진 수 : 8700 | 정확도:  98.55
# 확인한 사진 수 : 8800 | 정확도:  98.55
# 확인한 사진 수 : 8900 | 정확도:  98.52
# 확인한 사진 수 : 9000 | 정확도:  98.53
# 확인한 사진 수 : 9100 | 정확도:  98.53
# 확인한 사진 수 : 9200 | 정확도:  98.54
# 확인한 사진 수 : 9300 | 정확도:  98.53
# 확인한 사진 수 : 9400 | 정확도:  98.51
# 확인한 사진 수 : 9500 | 정확도:  98.49
# 확인한 사진 수 : 9600 | 정확도:  98.46
# 확인한 사진 수 : 9700 | 정확도:  98.44
# 확인한 사진 수 : 9800 | 정확도:  98.44
# 확인한 사진 수 : 9900 | 정확도:  98.4
# 확인한 사진 수 : 10000 | 정확도:  98.42
# 확인한 사진 수 : 10100 | 정확도:  98.43
# 확인한 사진 수 : 10200 | 정확도:  98.4
# 확인한 사진 수 : 10300 | 정확도:  98.4
# 확인한 사진 수 : 10400 | 정확도:  98.37
# 확인한 사진 수 : 10500 | 정확도:  98.38
# 확인한 사진 수 : 10600 | 정확도:  98.39
# 확인한 사진 수 : 10700 | 정확도:  98.39
# 확인한 사진 수 : 10800 | 정확도:  98.41
# 확인한 사진 수 : 10900 | 정확도:  98.42
# 확인한 사진 수 : 11000 | 정확도:  98.44
# 확인한 사진 수 : 11100 | 정확도:  98.45
# 확인한 사진 수 : 11200 | 정확도:  98.46
# 확인한 사진 수 : 11300 | 정확도:  98.48
# 확인한 사진 수 : 11400 | 정확도:  98.47
# 확인한 사진 수 : 11500 | 정확도:  98.49
# 확인한 사진 수 : 11600 | 정확도:  98.5
# 확인한 사진 수 : 11700 | 정확도:  98.51
# 확인한 사진 수 : 11800 | 정확도:  98.53
# 확인한 사진 수 : 11900 | 정확도:  98.54
# 확인한 사진 수 : 12000 | 정확도:  98.55
# 확인한 사진 수 : 12100 | 정확도:  98.55
# 확인한 사진 수 : 12200 | 정확도:  98.56
# 확인한 사진 수 : 12300 | 정확도:  98.57
# LEFT 를 못맞춘 경우의 수: 64
# RIGHT 를 못맞춘 경우의 수: 39
# FORWARD 를 못맞춘 경우의 수: 74
# ETC 를 못맞춘 경우의 수: 0

# %%
import tensorflow as tf
import scipy.misc
import model
# from subprocess import call
# import time
import csv
import numpy as np
import config as cfg
import cv2

sess = tf.InteractiveSession()
saver = tf.train.Saver()
saver.restore(sess, "save/model.ckpt")

xs = []
ys = []

increased_path = '../dataset/20200414-revised/3-increased'
with open(increased_path + '/data.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=',', quotechar='|')
    for row in spamreader:
        # print(row[0], row[1])
        xs.append(row[0])
        ys.append(row[1])

# print(xs[0])

"""
# 이미지를 읽고, 크기변환, normalize
cv2.resize(cv2.imread(filepath)[cfg.modelheight:], dsize=(200, 66)) / 255.0)

# 예시로 출력 해 보자
# cv2.imshow("src : " + str(y_out[i]), x_out[i])
# print('filepath : ' + filepath)
# cv2.waitKey(0)

def getDirectionString(dir):
    if dir == 0:  # 0 정지!!!
        return 'Stop'
    elif dir == 1:  # 1 = 좌회전
        return 'Left'
    elif int(row[1]) == 2:  # 2 = 전진
        return 'Forward'
    elif int(row[1]) == 3:  # 3 = 우회전
        return 'Right'
    
    return 'Error'
"""
i = 0
correct_num = 0
missed_forward = 0
missed_left = 0
missed_right = 0
missed_etc = 0

# while(cv2.waitKey(10) != ord('q')):
for i in range(len(xs)):
    filepath = increased_path + '/' + xs[i]
    # full_image = scipy.misc.imread(filepath, mode="RGB")
    full_image = cv2.imread(filepath)
    # image_feed2model = scipy.misc.imresize(full_image[cfg.modelheight:], [66, 200]) / 255.0
    image_feed2model = cv2.resize(full_image[cfg.modelheight:], dsize=(200, 66)) / 255.0
    # image_largescale = scipy.misc.imresize(full_image[cfg.modelheight:], [66 * 3, 200 * 3])
    image_largescale = cv2.resize(full_image[cfg.modelheight:], dsize=(200*3, 66*3)) / 255.0
    
    degrees = model.y.eval(feed_dict={model.x: [image_feed2model], model.keep_prob: 1.0})
    # print("Label y: " + ys[i], 'prediced value:', np.argmax(degrees, axis=1))
    if False:
        # cv2.imshow("Feed", cv2.cvtColor(image_largescale, cv2.COLOR_RGB2BGR))
        cv2.imshow("Feed", image_largescale)
        # cv2.imshow("Original", cv2.cvtColor(full_image, cv2.COLOR_RGB2BGR))
        cv2.imshow("Original", full_image)

    if int(ys[i]) == np.argmax(degrees, axis=1):
        correct_num += 1
    else:
        if int(ys[i]) == 1:  # LEFT
            missed_left = missed_left + 1
        elif int(ys[i]) == 2:  # FORWARD
            missed_forward = missed_forward + 1
        elif int(ys[i]) == 3:  # RIGHT
            missed_right = missed_right + 1
        else:  # etc
            missed_etc = missed_etc + 1

    if (i > 0) and (i % 100 == 0):
        print('확인한 사진 수 :', i, '| 정확도: ', round((correct_num/i)*100, 2))


# summary
print('LEFT 를 못맞춘 경우의 수: ' + str(missed_left))
print('RIGHT 를 못맞춘 경우의 수: ' + str(missed_right))
print('FORWARD 를 못맞춘 경우의 수: ' + str(missed_forward))
print('ETC 를 못맞춘 경우의 수: ' + str(missed_etc))

cv2.destroyAllWindows()

# THE END
# Out:
# WARNING:tensorflow:From /tf/student-workspace/model.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /tf/student-workspace/model.py:6: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /tf/student-workspace/model.py:72: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# model read
# INFO:tensorflow:Restoring parameters from save/model.ckpt
# 확인한 사진 수 : 100 | 정확도:  101.0
# 확인한 사진 수 : 200 | 정확도:  94.5
# 확인한 사진 수 : 300 | 정확도:  91.67
# 확인한 사진 수 : 400 | 정확도:  93.25
# 확인한 사진 수 : 500 | 정확도:  94.6
# 확인한 사진 수 : 600 | 정확도:  93.83
# 확인한 사진 수 : 700 | 정확도:  94.71
# 확인한 사진 수 : 800 | 정확도:  93.88
# 확인한 사진 수 : 900 | 정확도:  94.33
# 확인한 사진 수 : 1000 | 정확도:  94.0
# 확인한 사진 수 : 1100 | 정확도:  93.45
# 확인한 사진 수 : 1200 | 정확도:  93.83
# 확인한 사진 수 : 1300 | 정확도:  93.69
# 확인한 사진 수 : 1400 | 정확도:  93.21
# 확인한 사진 수 : 1500 | 정확도:  93.67
# 확인한 사진 수 : 1600 | 정확도:  93.38
# 확인한 사진 수 : 1700 | 정확도:  92.59
# 확인한 사진 수 : 1800 | 정확도:  92.5
# 확인한 사진 수 : 1900 | 정확도:  92.68
# 확인한 사진 수 : 2000 | 정확도:  92.25
# 확인한 사진 수 : 2100 | 정확도:  92.48
# 확인한 사진 수 : 2200 | 정확도:  92.73
# 확인한 사진 수 : 2300 | 정확도:  92.61
# 확인한 사진 수 : 2400 | 정확도:  92.62
# 확인한 사진 수 : 2500 | 정확도:  92.92
# 확인한 사진 수 : 2600 | 정확도:  93.08
# 확인한 사진 수 : 2700 | 정확도:  93.0
# 확인한 사진 수 : 2800 | 정확도:  93.25
# 확인한 사진 수 : 2900 | 정확도:  93.21
# 확인한 사진 수 : 3000 | 정확도:  93.3
# 확인한 사진 수 : 3100 | 정확도:  93.48
# 확인한 사진 수 : 3200 | 정확도:  93.5
# 확인한 사진 수 : 3300 | 정확도:  93.64
# 확인한 사진 수 : 3400 | 정확도:  93.56
# 확인한 사진 수 : 3500 | 정확도:  93.6
# 확인한 사진 수 : 3600 | 정확도:  93.67
# 확인한 사진 수 : 3700 | 정확도:  93.51
# 확인한 사진 수 : 3800 | 정확도:  93.18
# 확인한 사진 수 : 3900 | 정확도:  93.05
# 확인한 사진 수 : 4000 | 정확도:  92.9
# 확인한 사진 수 : 4100 | 정확도:  92.88
# 확인한 사진 수 : 4200 | 정확도:  93.0
# 확인한 사진 수 : 4300 | 정확도:  93.05
# 확인한 사진 수 : 4400 | 정확도:  93.09
# 확인한 사진 수 : 4500 | 정확도:  93.18
# 확인한 사진 수 : 4600 | 정확도:  93.15
# 확인한 사진 수 : 4700 | 정확도:  93.3
# 확인한 사진 수 : 4800 | 정확도:  93.38
# 확인한 사진 수 : 4900 | 정확도:  93.33
# 확인한 사진 수 : 5000 | 정확도:  93.32
# 확인한 사진 수 : 5100 | 정확도:  93.45
# 확인한 사진 수 : 5200 | 정확도:  93.54
# 확인한 사진 수 : 5300 | 정확도:  93.3
# 확인한 사진 수 : 5400 | 정확도:  93.2
# 확인한 사진 수 : 5500 | 정확도:  93.24
# 확인한 사진 수 : 5600 | 정확도:  93.18
# 확인한 사진 수 : 5700 | 정확도:  93.09
# 확인한 사진 수 : 5800 | 정확도:  93.03
# 확인한 사진 수 : 5900 | 정확도:  93.05
# 확인한 사진 수 : 6000 | 정확도:  92.92
# 확인한 사진 수 : 6100 | 정확도:  92.97
# 확인한 사진 수 : 6200 | 정확도:  92.98
# 확인한 사진 수 : 6300 | 정확도:  93.02
# 확인한 사진 수 : 6400 | 정확도:  93.03
# 확인한 사진 수 : 6500 | 정확도:  92.94
# 확인한 사진 수 : 6600 | 정확도:  92.98
# 확인한 사진 수 : 6700 | 정확도:  93.01
# 확인한 사진 수 : 6800 | 정확도:  93.1
# 확인한 사진 수 : 6900 | 정확도:  93.12
# 확인한 사진 수 : 7000 | 정확도:  93.07
# 확인한 사진 수 : 7100 | 정확도:  93.11
# 확인한 사진 수 : 7200 | 정확도:  93.19
# 확인한 사진 수 : 7300 | 정확도:  93.19
# 확인한 사진 수 : 7400 | 정확도:  93.12
# 확인한 사진 수 : 7500 | 정확도:  93.15
# 확인한 사진 수 : 7600 | 정확도:  93.17
# 확인한 사진 수 : 7700 | 정확도:  93.21
# 확인한 사진 수 : 7800 | 정확도:  93.19
# 확인한 사진 수 : 7900 | 정확도:  93.25
# 확인한 사진 수 : 8000 | 정확도:  93.12
# 확인한 사진 수 : 8100 | 정확도:  93.09
# 확인한 사진 수 : 8200 | 정확도:  93.05
# 확인한 사진 수 : 8300 | 정확도:  93.1
# 확인한 사진 수 : 8400 | 정확도:  93.07
# 확인한 사진 수 : 8500 | 정확도:  93.06
# 확인한 사진 수 : 8600 | 정확도:  93.14
# 확인한 사진 수 : 8700 | 정확도:  92.95
# 확인한 사진 수 : 8800 | 정확도:  92.93
# 확인한 사진 수 : 8900 | 정확도:  93.0
# 확인한 사진 수 : 9000 | 정확도:  93.03
# 확인한 사진 수 : 9100 | 정확도:  93.07
# 확인한 사진 수 : 9200 | 정확도:  92.97
# 확인한 사진 수 : 9300 | 정확도:  93.02
# 확인한 사진 수 : 9400 | 정확도:  93.06
# 확인한 사진 수 : 9500 | 정확도:  93.11
# 확인한 사진 수 : 9600 | 정확도:  93.1
# 확인한 사진 수 : 9700 | 정확도:  93.15
# 확인한 사진 수 : 9800 | 정확도:  93.2
# 확인한 사진 수 : 9900 | 정확도:  93.24
# 확인한 사진 수 : 10000 | 정확도:  93.29
# 확인한 사진 수 : 10100 | 정확도:  93.34
# 확인한 사진 수 : 10200 | 정확도:  93.22
# 확인한 사진 수 : 10300 | 정확도:  93.22
# 확인한 사진 수 : 10400 | 정확도:  93.2
# 확인한 사진 수 : 10500 | 정확도:  93.19
# 확인한 사진 수 : 10600 | 정확도:  93.24
# 확인한 사진 수 : 10700 | 정확도:  93.15
# 확인한 사진 수 : 10800 | 정확도:  93.19
# 확인한 사진 수 : 10900 | 정확도:  93.23
# 확인한 사진 수 : 11000 | 정확도:  93.29
# 확인한 사진 수 : 11100 | 정확도:  93.35
# 확인한 사진 수 : 11200 | 정확도:  93.41
# 확인한 사진 수 : 11300 | 정확도:  93.46
# 확인한 사진 수 : 11400 | 정확도:  93.52
# 확인한 사진 수 : 11500 | 정확도:  93.57
# 확인한 사진 수 : 11600 | 정확도:  93.63
# 확인한 사진 수 : 11700 | 정확도:  93.68
# 확인한 사진 수 : 11800 | 정확도:  93.74
# 확인한 사진 수 : 11900 | 정확도:  93.77
# 확인한 사진 수 : 12000 | 정확도:  93.83
# 확인한 사진 수 : 12100 | 정확도:  93.85
# 확인한 사진 수 : 12200 | 정확도:  93.9
# 확인한 사진 수 : 12300 | 정확도:  93.95
# 확인한 사진 수 : 12400 | 정확도:  94.0
# 확인한 사진 수 : 12500 | 정확도:  94.03
# 확인한 사진 수 : 12600 | 정확도:  94.07
# 확인한 사진 수 : 12700 | 정확도:  94.12
# 확인한 사진 수 : 12800 | 정확도:  94.15
# 확인한 사진 수 : 12900 | 정확도:  94.19
# 확인한 사진 수 : 13000 | 정확도:  94.22
# 확인한 사진 수 : 13100 | 정확도:  94.27
# 확인한 사진 수 : 13200 | 정확도:  94.31
# 확인한 사진 수 : 13300 | 정확도:  94.35
# 확인한 사진 수 : 13400 | 정확도:  94.4
# 확인한 사진 수 : 13500 | 정확도:  94.42
# 확인한 사진 수 : 13600 | 정확도:  94.46
# 확인한 사진 수 : 13700 | 정확도:  94.5
# 확인한 사진 수 : 13800 | 정확도:  94.54
# 확인한 사진 수 : 13900 | 정확도:  94.58
# 확인한 사진 수 : 14000 | 정확도:  94.61
# 확인한 사진 수 : 14100 | 정확도:  94.61
# 확인한 사진 수 : 14200 | 정확도:  94.59
# 확인한 사진 수 : 14300 | 정확도:  94.62
# 확인한 사진 수 : 14400 | 정확도:  94.62
# 확인한 사진 수 : 14500 | 정확도:  94.65
# 확인한 사진 수 : 14600 | 정확도:  94.68
# 확인한 사진 수 : 14700 | 정확도:  94.71
# 확인한 사진 수 : 14800 | 정확도:  94.65
# 확인한 사진 수 : 14900 | 정확도:  94.68
# 확인한 사진 수 : 15000 | 정확도:  94.67
# 확인한 사진 수 : 15100 | 정확도:  94.66
# 확인한 사진 수 : 15200 | 정확도:  94.68
# 확인한 사진 수 : 15300 | 정확도:  94.69
# 확인한 사진 수 : 15400 | 정확도:  94.72
# 확인한 사진 수 : 15500 | 정확도:  94.74
# 확인한 사진 수 : 15600 | 정확도:  94.74
# 확인한 사진 수 : 15700 | 정확도:  94.73
# 확인한 사진 수 : 15800 | 정확도:  94.77
# 확인한 사진 수 : 15900 | 정확도:  94.75
# 확인한 사진 수 : 16000 | 정확도:  94.76
# 확인한 사진 수 : 16100 | 정확도:  94.77
# 확인한 사진 수 : 16200 | 정확도:  94.75
# 확인한 사진 수 : 16300 | 정확도:  94.77
# 확인한 사진 수 : 16400 | 정확도:  94.8
# 확인한 사진 수 : 16500 | 정확도:  94.8
# 확인한 사진 수 : 16600 | 정확도:  94.81
# 확인한 사진 수 : 16700 | 정확도:  94.81
# 확인한 사진 수 : 16800 | 정확도:  94.82
# 확인한 사진 수 : 16900 | 정확도:  94.85
# 확인한 사진 수 : 17000 | 정확도:  94.88
# 확인한 사진 수 : 17100 | 정확도:  94.91
# 확인한 사진 수 : 17200 | 정확도:  94.91
# 확인한 사진 수 : 17300 | 정확도:  94.94
# 확인한 사진 수 : 17400 | 정확도:  94.97
# 확인한 사진 수 : 17500 | 정확도:  94.99
# 확인한 사진 수 : 17600 | 정확도:  95.01
# 확인한 사진 수 : 17700 | 정확도:  95.04
# 확인한 사진 수 : 17800 | 정확도:  95.07
# 확인한 사진 수 : 17900 | 정확도:  95.09
# 확인한 사진 수 : 18000 | 정확도:  95.12
# 확인한 사진 수 : 18100 | 정확도:  95.15
# 확인한 사진 수 : 18200 | 정확도:  95.17
# 확인한 사진 수 : 18300 | 정확도:  95.2
# 확인한 사진 수 : 18400 | 정확도:  95.19
# 확인한 사진 수 : 18500 | 정확도:  95.21
# 확인한 사진 수 : 18600 | 정확도:  95.23
# 확인한 사진 수 : 18700 | 정확도:  95.25
# 확인한 사진 수 : 18800 | 정확도:  95.27
# 확인한 사진 수 : 18900 | 정확도:  95.29
# 확인한 사진 수 : 19000 | 정확도:  95.31
# 확인한 사진 수 : 19100 | 정확도:  95.32
# 확인한 사진 수 : 19200 | 정확도:  95.34
# 확인한 사진 수 : 19300 | 정확도:  95.34
# 확인한 사진 수 : 19400 | 정확도:  95.37
# 확인한 사진 수 : 19500 | 정확도:  95.39
# 확인한 사진 수 : 19600 | 정확도:  95.41
# 확인한 사진 수 : 19700 | 정확도:  95.42
# 확인한 사진 수 : 19800 | 정확도:  95.44
# 확인한 사진 수 : 19900 | 정확도:  95.45
# 확인한 사진 수 : 20000 | 정확도:  95.47
# 확인한 사진 수 : 20100 | 정확도:  95.5
# 확인한 사진 수 : 20200 | 정확도:  95.52
# 확인한 사진 수 : 20300 | 정확도:  95.54
# LEFT 를 못맞춘 경우의 수: 284
# RIGHT 를 못맞춘 경우의 수: 155
# FORWARD 를 못맞춘 경우의 수: 467
# ETC 를 못맞춘 경우의 수: 0
